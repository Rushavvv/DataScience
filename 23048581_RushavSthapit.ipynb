# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
dataSet = pd.read_csv('dataSet.csv')
dataSet.info()
# Out:
# /var/folders/12/0jmx_6gj56vc7gk93q0s_hnc0000gn/T/ipykernel_20716/1051291397.py:1: DtypeWarning: Columns (48,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataSet = pd.read_csv('dataSet.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300698 entries, 0 to 300697
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      300698 non-null  int64
#  1   Created Date                    300698 non-null  object
#  2   Closed Date                     298534 non-null  object
#  3   Agency                          300698 non-null  object
#  4   Agency Name                     300698 non-null  object
#  5   Complaint Type                  300698 non-null  object
#  6   Descriptor                      294784 non-null  object
#  7   Location Type                   300567 non-null  object
# ...

# %%
dataF = pd.DataFrame(dataSet['Complaint Type'].unique())
dataF
# Out:
#                             0
# 0     Noise - Street/Sidewalk
# 1            Blocked Driveway
# 2             Illegal Parking
# 3            Derelict Vehicle
# 4          Noise - Commercial
# 5    Noise - House of Worship
# 6       Posting Advertisement
# 7             Noise - Vehicle
# 8                Animal Abuse
# 9                     Vending
# 10                    Traffic
# 11                   Drinking
# 12  Bike/Roller/Skate Chronic
# 13                Panhandling
# 14               Noise - Park
# 15        Homeless Encampment
# 16        Urinating in Public
# 17                   Graffiti
# 18           Disorderly Youth
# 19          Illegal Fireworks
# 20            Ferry Complaint
# 21              Agency Issues
# 22                   Squeegee
# 23           Animal in a Park

# %% [markdown]
# dataSet.dropna(how = 'all')

# %%
dataSet.shape
# Out:
# (300698, 53)

# %%
dataSet['Park Borough'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Park Borough'>

# %% [markdown]
# dataSet['Park Borough'].value_counts().plot()

# %%
dataSet.isnull().sum()
# Out:
# Unique Key                             0
# Created Date                           0
# Closed Date                         2164
# Agency                                 0
# Agency Name                            0
# Complaint Type                         0
# Descriptor                          5914
# Location Type                        131
# Incident Zip                        2615
# Incident Address                   44410
# Street Name                        44410
# Cross Street 1                     49279
# Cross Street 2                     49779
# Intersection Street 1             256840
# Intersection Street 2             257336
# Address Type                        2815
# City                                2614
# Landmark                          300349
# Facility Type                       2171
# Status                                 0
# Due Date                               3
# Resolution Description                 0
# Resolution Action Updated Date      2187
# ...

# %%
df = pd.DataFrame(dataSet)

# %%
df
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 0         32310363  12/31/2015 11:59:45 PM           01-01-16 0:55   NYPD
# 1         32309934  12/31/2015 11:59:44 PM           01-01-16 1:26   NYPD
# 2         32309159  12/31/2015 11:59:29 PM           01-01-16 4:51   NYPD
# 3         32305098  12/31/2015 11:57:46 PM           01-01-16 7:43   NYPD
# 4         32306529  12/31/2015 11:56:58 PM           01-01-16 3:24   NYPD
# ...            ...                     ...                     ...    ...
# 300693    30281872  03/29/2015 12:33:41 AM                     NaN   NYPD
# 300694    30281230  03/29/2015 12:33:28 AM  03/29/2015 02:33:59 AM   NYPD
# 300695    30283424  03/29/2015 12:33:03 AM  03/29/2015 03:40:20 AM   NYPD
# 300696    30280004  03/29/2015 12:33:02 AM  03/29/2015 04:38:35 AM   NYPD
# 300697    30281825  03/29/2015 12:33:01 AM  03/29/2015 04:41:50 AM   NYPD
#
#                             Agency Name           Complaint Type  \
# ...

# %%
df['Created Date'] = pd.to_datetime(df['Created Date'],format='mixed', errors='coerce')
df['Closed Date'] = pd.to_datetime(df['Closed Date'],format='mixed', errors='coerce')

# %%
df['Request_Closing_Time'] = (df['Closed Date'] - df['Created Date']).dt.days

# %%
df
# Out:
#         Unique Key        Created Date         Closed Date Agency  \
# 0         32310363 2015-12-31 23:59:45 2016-01-01 00:55:00   NYPD
# 1         32309934 2015-12-31 23:59:44 2016-01-01 01:26:00   NYPD
# 2         32309159 2015-12-31 23:59:29 2016-01-01 04:51:00   NYPD
# 3         32305098 2015-12-31 23:57:46 2016-01-01 07:43:00   NYPD
# 4         32306529 2015-12-31 23:56:58 2016-01-01 03:24:00   NYPD
# ...            ...                 ...                 ...    ...
# 300693    30281872 2015-03-29 00:33:41                 NaT   NYPD
# 300694    30281230 2015-03-29 00:33:28 2015-03-29 02:33:59   NYPD
# 300695    30283424 2015-03-29 00:33:03 2015-03-29 03:40:20   NYPD
# 300696    30280004 2015-03-29 00:33:02 2015-03-29 04:38:35   NYPD
# 300697    30281825 2015-03-29 00:33:01 2015-03-29 04:41:50   NYPD
#
#                             Agency Name           Complaint Type  \
# 0       New York City Police Department  Noise - Street/Sidewalk
# ...

# %%
df.drop(columns = ['Agency Name','Incident Address','Street Name','Cross Street 1','Cross Street 2','Intersection Street 1', 'Intersection Street 2','Address Type','Park Facility Name','Park Borough','School Name', 'School Number','School Region','School Code','School Phone Number','School Address','School City',
'School State','School Zip','School Not Found','School or Citywide Complaint','Taxi Pick Up Location','Vehicle Type', 'Taxi Company Borough','Bridge Highway Name','Bridge Highway Direction',
'Road Ramp','Bridge Highway Segment','Garage Lot Name','Ferry Direction','Ferry Terminal Name','Landmark',
'X Coordinate (State Plane)','Y Coordinate (State Plane)','Due Date','Resolution Action Updated Date','Community Board','Facility Type',
'Location'], inplace=True)

# %%
df
# Out:
#         Unique Key        Created Date         Closed Date Agency  \
# 0         32310363 2015-12-31 23:59:45 2016-01-01 00:55:00   NYPD
# 1         32309934 2015-12-31 23:59:44 2016-01-01 01:26:00   NYPD
# 2         32309159 2015-12-31 23:59:29 2016-01-01 04:51:00   NYPD
# 3         32305098 2015-12-31 23:57:46 2016-01-01 07:43:00   NYPD
# 4         32306529 2015-12-31 23:56:58 2016-01-01 03:24:00   NYPD
# ...            ...                 ...                 ...    ...
# 300693    30281872 2015-03-29 00:33:41                 NaT   NYPD
# 300694    30281230 2015-03-29 00:33:28 2015-03-29 02:33:59   NYPD
# 300695    30283424 2015-03-29 00:33:03 2015-03-29 03:40:20   NYPD
# 300696    30280004 2015-03-29 00:33:02 2015-03-29 04:38:35   NYPD
# 300697    30281825 2015-03-29 00:33:01 2015-03-29 04:41:50   NYPD
#
#                  Complaint Type                    Descriptor  \
# 0       Noise - Street/Sidewalk              Loud Music/Party
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#         Unique Key        Created Date         Closed Date Agency  \
# 0         32310363 2015-12-31 23:59:45 2016-01-01 00:55:00   NYPD
# 1         32309934 2015-12-31 23:59:44 2016-01-01 01:26:00   NYPD
# 2         32309159 2015-12-31 23:59:29 2016-01-01 04:51:00   NYPD
# 3         32305098 2015-12-31 23:57:46 2016-01-01 07:43:00   NYPD
# 4         32306529 2015-12-31 23:56:58 2016-01-01 03:24:00   NYPD
# ...            ...                 ...                 ...    ...
# 300692    30281370 2015-03-29 00:34:32 2015-03-29 01:13:01   NYPD
# 300694    30281230 2015-03-29 00:33:28 2015-03-29 02:33:59   NYPD
# 300695    30283424 2015-03-29 00:33:03 2015-03-29 03:40:20   NYPD
# 300696    30280004 2015-03-29 00:33:02 2015-03-29 04:38:35   NYPD
# 300697    30281825 2015-03-29 00:33:01 2015-03-29 04:41:50   NYPD
#
#                  Complaint Type                    Descriptor  \
# 0       Noise - Street/Sidewalk              Loud Music/Party
# ...

# %%
dataSet.head()
# Out:
#    Unique Key            Created Date    Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01-01-16 0:55   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01-01-16 1:26   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01-01-16 4:51   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01-01-16 7:43   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01-01-16 3:24   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %%
for column in df.columns:
    print(f"\n Column: {column}")
    print(f"Unique Values ({df[column].unique()}):")
    print(df[column].nunique())
# Out:
#  Column: Unique Key
# Unique Values ([32310363 32309934 32309159 ... 30283424 30280004 30281825]):
# 291107
#
#  Column: Created Date
# Unique Values (<DatetimeArray>
# ['2015-12-31 23:59:45', '2015-12-31 23:59:44', '2015-12-31 23:59:29',
#  '2015-12-31 23:57:46', '2015-12-31 23:56:58', '2015-12-31 23:56:30',
#  '2015-12-31 23:55:32', '2015-12-31 23:54:05', '2015-12-31 23:53:58',
#  '2015-12-31 23:52:58',
#  ...
#  '2015-03-29 00:42:48', '2015-03-29 00:37:15', '2015-03-29 00:35:28',
#  '2015-03-29 00:35:23', '2015-03-29 00:35:04', '2015-03-29 00:34:32',
#  '2015-03-29 00:33:28', '2015-03-29 00:33:03', '2015-03-29 00:33:02',
#  '2015-03-29 00:33:01']
# Length: 251970, dtype: datetime64[ns]):
# 251970
#
#  Column: Closed Date
# Unique Values (<DatetimeArray>
# ['2016-01-01 00:55:00', '2016-01-01 01:26:00', '2016-01-01 04:51:00',
#  '2016-01-01 07:43:00', '2016-01-01 03:24:00', '2016-01-01 01:50:00',
#  '2016-01-01 01:53:00', '2016-01-01 01:42:00', '2016-01-01 08:27:00',
# ...

# %%
numerical_df = df.select_dtypes(include = 'number')
for column in numerical_df.columns:
    print(f'\n Statistical data of {column}: ')
    print(f' The Sum is {numerical_df[column].sum()}')
    print(f' The Mean is {numerical_df[column].mean()}')
    print(f' The Standard Deviation is {numerical_df[column].std()}')
    print(f' The Skewness is {numerical_df[column].skew()}')
    print(f' The Kurtosis is {numerical_df[column].kurt()}')
# Out:
#  Statistical data of Unique Key:
#  The Sum is 9112107955295
#  The Mean is 31301576.242738925
#  The Standard Deviation is 575377.7387071877
#  The Skewness is 0.016897722422296077
#  The Kurtosis is -1.1765926558306596
#
#  Statistical data of Incident Zip:
#  The Sum is 3160833212.0
#  The Mean is 10857.977348535074
#  The Standard Deviation is 580.2807740122854
#  The Skewness is -2.553955898131983
#  The Kurtosis is 37.827777247855444
#
#  Statistical data of Latitude:
#  The Sum is 11855530.75877829
#  The Mean is 40.72568079358549
#  The Standard Deviation is 0.08241087015112669
#  The Skewness is 0.123114382634822
#  The Kurtosis is -0.7348182547719988
#
#  Statistical data of Longitude:
#  The Sum is -21520095.167681944
#  The Mean is -73.92503501352404
#  The Standard Deviation is 0.07865355626291953
#  The Skewness is -0.3127386420474719
#  The Kurtosis is 1.455600458821316
#
#  Statistical data of Request_Closing_Time:
#  The Sum is 4658.0
# ...

# %%
print(f'The Correlation of all the columns: \n{numerical_df.corr()}')
# Out:
# The Correlation of all the columns:
#                       Unique Key  Incident Zip  Latitude  Longitude  \
# Unique Key              1.000000      0.025492 -0.032613  -0.008621
# Incident Zip            0.025492      1.000000 -0.499081   0.385934
# Latitude               -0.032613     -0.499081  1.000000   0.368819
# Longitude              -0.008621      0.385934  0.368819   1.000000
# Request_Closing_Time    0.034167      0.018569  0.013524   0.060694
#
#                       Request_Closing_Time
# Unique Key                        0.034167
# Incident Zip                      0.018569
# Latitude                          0.013524
# Longitude                         0.060694
# Request_Closing_Time              1.000000
