# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/anaconda3/lib/python3.12/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /opt/anaconda3/lib/python3.12/site-packages (from opencv-python) (1.26.4)

# %%
import cv2

cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

while True:
    ret, img= cap.read()
    cv2.imshow('Webcam', img)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 2025-03-25 10:21:39.618 python[5191:208891] +[IMKClient subclass]: chose IMKClient_Legacy
# 2025-03-25 10:21:39.618 python[5191:208891] +[IMKInputSession subclass]: chose IMKInputSession_Legacy

# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /opt/anaconda3/lib/python3.12/site-packages (8.3.95)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (3.9.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (0.17.2)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.13.2)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)

# %%
from ultralytics import YOLO
model = YOLO("yolo-Weights/yolov8n.pt")

# %%
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]

# %%
import cv2

cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

while True:
    ret, img= cap.read()
    results = model(img, stream=True)

    cv2.imshow('Webcam', img)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING ⚠️ 'source' is missing. Using 'source=/opt/anaconda3/lib/python3.12/site-packages/ultralytics/assets'.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[8], line 11
#       8 ret, img= cap.read()
#       9 results = model(img, stream=True)
# ---> 11 cv2.imshow('Webcam', img)
#      13 if cv2.waitKey(1) == ord('q'):
#      14     break
#
# error: OpenCV(4.11.0) /Users/runner/work/opencv-python/opencv-python/opencv/modules/highgui/src/window.cpp:973: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'

# %%
from ultralytics import YOLO
import cv2
import math 
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# model
model = YOLO("yolo-Weights/yolov8n.pt")

# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]


while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 166.2ms
# Confidence ---> 0.45
# Class name --> person
# Speed: 11.6ms preprocess, 166.2ms inference, 12.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 118.2ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.4ms preprocess, 118.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 90.5ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Speed: 1.4ms preprocess, 90.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 87.9ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.5ms preprocess, 87.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 87.3ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.2ms preprocess, 87.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 91.8ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.1ms preprocess, 91.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 88.7ms
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 1.3ms preprocess, 88.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 teddy bear, 87.8ms
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.38
# Class name --> teddy bear
# Speed: 1.3ms preprocess, 87.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.9ms
# Confidence ---> 0.62
# Class name --> person
# Speed: 1.1ms preprocess, 95.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 teddy bear, 110.6ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.27
# Class name --> teddy bear
# Speed: 1.5ms preprocess, 110.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 102.2ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.3ms preprocess, 102.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 99.6ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.38
# Class name --> chair
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.1ms preprocess, 99.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 teddy bear, 99.2ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.43
# Class name --> teddy bear
# Confidence ---> 0.36
# Class name --> chair
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.1ms preprocess, 99.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 145.5ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.35
# Class name --> chair
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.5ms preprocess, 145.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 93.2ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.3
# Class name --> chair
# Speed: 2.0ms preprocess, 93.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 90.0ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.27
# Class name --> chair
# Speed: 2.2ms preprocess, 90.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 106.4ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 2.6ms preprocess, 106.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 87.6ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.5
# Class name --> chair
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.3ms preprocess, 87.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 85.1ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.28
# Class name --> chair
# Speed: 1.1ms preprocess, 85.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 86.3ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
# Speed: 1.3ms preprocess, 86.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 86.3ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.3
# Class name --> chair
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.4ms preprocess, 86.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 81.5ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.38
# Class name --> chair
# Confidence ---> 0.34
# Class name --> person
# Speed: 1.2ms preprocess, 81.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 84.0ms
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.2ms preprocess, 84.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 1 teddy bear, 79.1ms
# Confidence ---> 0.33
# Class name --> cat
# Confidence ---> 0.27
# Class name --> teddy bear
# Speed: 1.2ms preprocess, 79.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 82.1ms
# Speed: 1.2ms preprocess, 82.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 75.8ms
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.2ms preprocess, 75.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.3ms
# Speed: 1.2ms preprocess, 78.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 78.8ms
# Confidence ---> 0.54
# Class name --> cat
# Speed: 1.2ms preprocess, 78.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.3ms
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.2ms preprocess, 79.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 80.7ms
# Confidence ---> 0.39
# Class name --> cat
# Speed: 1.1ms preprocess, 80.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 77.2ms
# Confidence ---> 0.36
# Class name --> cat
# Speed: 1.0ms preprocess, 77.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 81.1ms
# Confidence ---> 0.51
# Class name --> cat
# Speed: 1.0ms preprocess, 81.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 78.7ms
# Confidence ---> 0.62
# Class name --> cat
# Speed: 1.1ms preprocess, 78.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 79.9ms
# Confidence ---> 0.38
# Class name --> cat
# Speed: 1.1ms preprocess, 79.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 dog, 84.4ms
# Confidence ---> 0.28
# Class name --> dog
# Speed: 1.0ms preprocess, 84.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 82.2ms
# Speed: 1.1ms preprocess, 82.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.7ms
# Confidence ---> 0.54
# Class name --> person
# Speed: 1.2ms preprocess, 82.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 87.9ms
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.2ms preprocess, 87.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 76.9ms
# Confidence ---> 0.32
# Class name --> cat
# Speed: 1.3ms preprocess, 76.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 80.3ms
# Speed: 1.2ms preprocess, 80.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 77.3ms
# Confidence ---> 0.34
# Class name --> person
# Speed: 1.1ms preprocess, 77.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 75.4ms
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.26
# Class name --> cat
# Speed: 1.2ms preprocess, 75.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cats, 78.8ms
# Confidence ---> 0.36
# Class name --> cat
# Confidence ---> 0.3
# Class name --> cat
# Speed: 1.2ms preprocess, 78.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 82.9ms
# Confidence ---> 0.56
# Class name --> cat
# Speed: 1.2ms preprocess, 82.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cats, 81.8ms
# Confidence ---> 0.39
# Class name --> cat
# Confidence ---> 0.32
# Class name --> cat
# Speed: 1.3ms preprocess, 81.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 79.7ms
# Confidence ---> 0.55
# Class name --> cat
# Speed: 1.3ms preprocess, 79.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 82.3ms
# Confidence ---> 0.59
# Class name --> cat
# Speed: 1.0ms preprocess, 82.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 81.1ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.6ms preprocess, 81.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.1ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.2ms preprocess, 84.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 77.6ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 1.1ms preprocess, 77.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 77.3ms
# Confidence ---> 0.56
# Class name --> cat
# Speed: 1.2ms preprocess, 77.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 79.0ms
# Confidence ---> 0.45
# Class name --> cat
# Speed: 1.3ms preprocess, 79.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 78.0ms
# Confidence ---> 0.39
# Class name --> cat
# Speed: 1.1ms preprocess, 78.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 77.6ms
# Confidence ---> 0.28
# Class name --> cat
# Speed: 1.3ms preprocess, 77.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 79.9ms
# Confidence ---> 0.49
# Class name --> cat
# Speed: 1.2ms preprocess, 79.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 1 dog, 78.9ms
# Confidence ---> 0.3
# Class name --> cat
# Confidence ---> 0.28
# Class name --> dog
# Speed: 1.3ms preprocess, 78.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 76.7ms
# Confidence ---> 0.31
# Class name --> cat
# Speed: 1.2ms preprocess, 76.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 77.2ms
# Confidence ---> 0.29
# Class name --> cat
# Speed: 1.2ms preprocess, 77.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 81.6ms
# Confidence ---> 0.33
# Class name --> cat
# Speed: 1.1ms preprocess, 81.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 79.0ms
# Speed: 1.2ms preprocess, 79.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 80.6ms
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.5ms preprocess, 80.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 80.3ms
# Confidence ---> 0.29
# Class name --> cat
# Speed: 1.2ms preprocess, 80.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 89.9ms
# Confidence ---> 0.32
# Class name --> cat
# Speed: 1.4ms preprocess, 89.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 96.0ms
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 1.3ms preprocess, 96.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 87.5ms
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.32
# Class name --> cat
# Speed: 1.3ms preprocess, 87.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 79.5ms
# Confidence ---> 0.43
# Class name --> cat
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.2ms preprocess, 79.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 82.4ms
# Speed: 1.3ms preprocess, 82.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 90.2ms
# Confidence ---> 0.33
# Class name --> cat
# Speed: 1.2ms preprocess, 90.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 79.5ms
# Confidence ---> 0.43
# Class name --> cat
# Speed: 1.3ms preprocess, 79.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 81.6ms
# Speed: 1.2ms preprocess, 81.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 84.8ms
# Confidence ---> 0.41
# Class name --> cat
# Speed: 1.3ms preprocess, 84.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 81.2ms
# Confidence ---> 0.26
# Class name --> cat
# Speed: 1.3ms preprocess, 81.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 dog, 86.3ms
# Confidence ---> 0.29
# Class name --> dog
# Speed: 1.9ms preprocess, 86.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 84.4ms
# Confidence ---> 0.32
# Class name --> cat
# Speed: 1.2ms preprocess, 84.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 88.2ms
# Confidence ---> 0.28
# Class name --> cat
# Speed: 1.3ms preprocess, 88.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 87.8ms
# Confidence ---> 0.4
# Class name --> cat
# Speed: 1.6ms preprocess, 87.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 dog, 97.4ms
# Confidence ---> 0.31
# Class name --> dog
# Speed: 1.3ms preprocess, 97.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 90.0ms
# Confidence ---> 0.26
# Class name --> cat
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.9ms preprocess, 90.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 85.3ms
# Confidence ---> 0.33
# Class name --> cat
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.3ms preprocess, 85.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 84.5ms
# Speed: 1.3ms preprocess, 84.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 82.2ms
# Confidence ---> 0.28
# Class name --> cat
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.3ms preprocess, 82.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 88.9ms
# Confidence ---> 0.28
# Class name --> cat
# Speed: 1.4ms preprocess, 88.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 84.1ms
# Speed: 1.1ms preprocess, 84.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 80.8ms
# Confidence ---> 0.29
# Class name --> cat
# Speed: 1.3ms preprocess, 80.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 84.1ms
# Confidence ---> 0.31
# Class name --> cat
# Speed: 1.4ms preprocess, 84.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 83.7ms
# Speed: 1.3ms preprocess, 83.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 79.0ms
# Speed: 1.6ms preprocess, 79.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 84.7ms
# Speed: 1.4ms preprocess, 84.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 84.5ms
# Confidence ---> 0.35
# Class name --> cat
# Speed: 1.3ms preprocess, 84.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 77.5ms
# Confidence ---> 0.48
# Class name --> cat
# Speed: 1.3ms preprocess, 77.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 84.9ms
# Confidence ---> 0.27
# Class name --> cat
# Speed: 1.4ms preprocess, 84.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 80.9ms
# Speed: 1.2ms preprocess, 80.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.5ms
# Speed: 1.5ms preprocess, 78.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 86.8ms
# Confidence ---> 0.35
# Class name --> cat
# Speed: 1.6ms preprocess, 86.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 1 cup, 83.3ms
# Confidence ---> 0.49
# Class name --> cup
# Confidence ---> 0.37
# Class name --> cat
# Speed: 1.2ms preprocess, 83.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 77.8ms
# Confidence ---> 0.55
# Class name --> cup
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.5ms preprocess, 77.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 1 cup, 81.6ms
# Confidence ---> 0.48
# Class name --> cup
# Confidence ---> 0.43
# Class name --> cat
# Speed: 1.9ms preprocess, 81.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 82.0ms
# Confidence ---> 0.48
# Class name --> cup
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.3ms preprocess, 82.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 1 cup, 77.4ms
# Confidence ---> 0.49
# Class name --> cat
# Confidence ---> 0.41
# Class name --> cup
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.5ms preprocess, 77.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 81.3ms
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.46
# Class name --> cup
# Speed: 1.7ms preprocess, 81.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 81.5ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.5
# Class name --> cup
# Speed: 1.3ms preprocess, 81.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 82.1ms
# Confidence ---> 0.27
# Class name --> cat
# Speed: 1.5ms preprocess, 82.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.2ms
# Speed: 1.3ms preprocess, 85.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 80.4ms
# Speed: 1.2ms preprocess, 80.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.7ms
# Speed: 1.8ms preprocess, 78.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 surfboard, 85.5ms
# Confidence ---> 0.28
# Class name --> surfboard
# Speed: 1.4ms preprocess, 85.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 baseball bat, 80.5ms
# Confidence ---> 0.26
# Class name --> baseball bat
# Speed: 1.1ms preprocess, 80.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 77.5ms
# Speed: 1.6ms preprocess, 77.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.1ms
# Speed: 1.5ms preprocess, 87.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.1ms
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.2ms preprocess, 83.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.6ms
# Confidence ---> 0.41
# Class name --> person
# Speed: 1.7ms preprocess, 79.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.6ms
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.4ms preprocess, 87.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.1ms
# Speed: 1.2ms preprocess, 87.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 81.1ms
# Speed: 1.5ms preprocess, 81.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.4ms
# Confidence ---> 0.45
# Class name --> person
# Speed: 1.3ms preprocess, 82.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 82.0ms
# Speed: 1.3ms preprocess, 82.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 79.2ms
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.6ms preprocess, 79.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 87.6ms
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Speed: 2.7ms preprocess, 87.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 95.5ms
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.2ms preprocess, 95.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 90.2ms
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 1.5ms preprocess, 90.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 90.5ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 1.5ms preprocess, 90.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 91.0ms
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.2ms preprocess, 91.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 83.9ms
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.5ms preprocess, 83.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 92.0ms
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.3ms preprocess, 92.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.3ms
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.1ms preprocess, 94.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 86.4ms
# Speed: 1.6ms preprocess, 86.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 90.2ms
# Speed: 1.2ms preprocess, 90.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.9ms
# Speed: 1.2ms preprocess, 89.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 80.4ms
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.7ms preprocess, 80.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 teddy bear, 89.8ms
# Confidence ---> 0.37
# Class name --> teddy bear
# Speed: 1.2ms preprocess, 89.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 90.8ms
# Speed: 1.2ms preprocess, 90.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 83.7ms
# Confidence ---> 0.4
# Class name --> cat
# Speed: 1.4ms preprocess, 83.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 88.0ms
# Confidence ---> 0.43
# Class name --> cat
# Speed: 1.3ms preprocess, 88.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 88.6ms
# Confidence ---> 0.29
# Class name --> cat
# Speed: 1.3ms preprocess, 88.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 82.3ms
# Speed: 1.5ms preprocess, 82.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 89.6ms
# Speed: 1.2ms preprocess, 89.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.7ms
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.2ms preprocess, 84.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.6ms
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.3ms preprocess, 83.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 87.5ms
# Confidence ---> 0.52
# Class name --> person
# Speed: 1.2ms preprocess, 87.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 89.2ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Speed: 3.6ms preprocess, 89.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 82.2ms
# Confidence ---> 0.37
# Class name --> cat
# Speed: 1.4ms preprocess, 82.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 91.0ms
# Confidence ---> 0.54
# Class name --> person
# Speed: 1.2ms preprocess, 91.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 85.2ms
# Confidence ---> 0.43
# Class name --> cat
# Speed: 1.2ms preprocess, 85.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 85.7ms
# Confidence ---> 0.34
# Class name --> cat
# Speed: 1.5ms preprocess, 85.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.5ms
# Confidence ---> 0.6
# Class name --> person
# Speed: 1.2ms preprocess, 90.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.7ms
# Confidence ---> 0.56
# Class name --> person
# Speed: 1.2ms preprocess, 84.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.7ms
# Confidence ---> 0.64
# Class name --> person
# Speed: 1.4ms preprocess, 82.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 89.7ms
# Confidence ---> 0.53
# Class name --> person
# Speed: 1.2ms preprocess, 89.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 86.7ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 1.3ms preprocess, 86.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 82.6ms
# Confidence ---> 0.56
# Class name --> person
# Speed: 1.4ms preprocess, 82.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 88.1ms
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 1.3ms preprocess, 88.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 83.4ms
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Speed: 1.1ms preprocess, 83.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 86.5ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Speed: 1.3ms preprocess, 86.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 90.9ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.36
# Class name --> cat
# Speed: 1.4ms preprocess, 90.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 teddy bear, 83.0ms
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.38
# Class name --> teddy bear
# Speed: 1.2ms preprocess, 83.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 83.9ms
# Confidence ---> 0.31
# Class name --> cat
# Speed: 1.7ms preprocess, 83.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 90.8ms
# Speed: 1.3ms preprocess, 90.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 83.7ms
# Confidence ---> 0.3
# Class name --> cat
# Speed: 1.1ms preprocess, 83.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 81.3ms
# Confidence ---> 0.46
# Class name --> cat
# Speed: 1.4ms preprocess, 81.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.7ms
# Speed: 1.2ms preprocess, 87.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 84.8ms
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.27
# Class name --> cat
# Speed: 1.1ms preprocess, 84.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 80.7ms
# Confidence ---> 0.47
# Class name --> person
# Speed: 1.3ms preprocess, 80.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 88.4ms
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 1.1ms preprocess, 88.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cat, 82.1ms
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.28
# Class name --> cat
# Speed: 1.1ms preprocess, 82.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.9ms
# Confidence ---> 0.47
# Class name --> person
# Speed: 1.3ms preprocess, 79.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 86.3ms
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.29
# Class name --> cat
# Speed: 1.2ms preprocess, 86.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 81.2ms
# Confidence ---> 0.26
# Class name --> cat
# Speed: 1.1ms preprocess, 81.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 80.2ms
# Speed: 1.3ms preprocess, 80.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 86.4ms
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.2ms preprocess, 86.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 81.4ms
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.2ms preprocess, 81.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 79.3ms
# Confidence ---> 0.29
# Class name --> cat
# Speed: 1.3ms preprocess, 79.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 84.1ms
# Speed: 1.2ms preprocess, 84.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 81.6ms
# Confidence ---> 0.26
# Class name --> cat
# Speed: 1.1ms preprocess, 81.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 81.0ms
# Confidence ---> 0.47
# Class name --> cat
# Speed: 1.2ms preprocess, 81.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cats, 87.1ms
# Confidence ---> 0.26
# Class name --> cat
# Confidence ---> 0.26
# Class name --> cat
# Speed: 1.2ms preprocess, 87.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.3ms
# Speed: 1.2ms preprocess, 88.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cats, 79.2ms
# Confidence ---> 0.45
# Class name --> cat
# Confidence ---> 0.31
# Class name --> cat
# Speed: 1.3ms preprocess, 79.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 88.7ms
# Confidence ---> 0.62
# Class name --> cat
# Speed: 1.2ms preprocess, 88.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 85.2ms
# Confidence ---> 0.45
# Class name --> cat
# Speed: 1.2ms preprocess, 85.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 81.0ms
# Confidence ---> 0.38
# Class name --> cat
# Speed: 1.3ms preprocess, 81.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 89.7ms
# Confidence ---> 0.34
# Class name --> cat
# Speed: 1.2ms preprocess, 89.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 1 dog, 80.1ms
# Confidence ---> 0.39
# Class name --> cat
# Confidence ---> 0.27
# Class name --> dog
# Speed: 1.2ms preprocess, 80.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 82.5ms
# Confidence ---> 0.38
# Class name --> cat
# Speed: 1.3ms preprocess, 82.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 91.1ms
# Speed: 1.2ms preprocess, 91.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 90.2ms
# Speed: 1.2ms preprocess, 90.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 84.6ms
# Speed: 1.3ms preprocess, 84.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 91.5ms
# Confidence ---> 0.36
# Class name --> cat
# Speed: 1.2ms preprocess, 91.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 baseball bat, 87.4ms
# Confidence ---> 0.37
# Class name --> baseball bat
# Speed: 1.2ms preprocess, 87.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 85.6ms
# Confidence ---> 0.28
# Class name --> cat
# Speed: 1.7ms preprocess, 85.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 87.9ms
# Speed: 1.2ms preprocess, 87.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 88.3ms
# Speed: 1.2ms preprocess, 88.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 86.8ms
# Confidence ---> 0.38
# Class name --> cat
# Speed: 2.3ms preprocess, 86.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 90.8ms
# Confidence ---> 0.41
# Class name --> cat
# Speed: 1.3ms preprocess, 90.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 90.1ms
# Confidence ---> 0.5
# Class name --> cat
# Speed: 1.2ms preprocess, 90.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 83.1ms
# Confidence ---> 0.35
# Class name --> cat
# Speed: 1.5ms preprocess, 83.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 90.0ms
# Speed: 1.3ms preprocess, 90.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 89.3ms
# Confidence ---> 0.38
# Class name --> cat
# Speed: 1.4ms preprocess, 89.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 suitcase, 82.0ms
# Confidence ---> 0.28
# Class name --> suitcase
# Speed: 1.3ms preprocess, 82.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 89.7ms
# Confidence ---> 0.26
# Class name --> cat
# Speed: 1.3ms preprocess, 89.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 89.2ms
# Confidence ---> 0.38
# Class name --> cat
# Speed: 1.3ms preprocess, 89.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 81.6ms
# Confidence ---> 0.33
# Class name --> cat
# Speed: 1.4ms preprocess, 81.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 1 suitcase, 89.3ms
# Confidence ---> 0.51
# Class name --> cat
# Confidence ---> 0.31
# Class name --> suitcase
# Speed: 1.3ms preprocess, 89.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 88.4ms
# Confidence ---> 0.33
# Class name --> cat
# Speed: 1.3ms preprocess, 88.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 83.6ms
# Speed: 1.9ms preprocess, 83.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
